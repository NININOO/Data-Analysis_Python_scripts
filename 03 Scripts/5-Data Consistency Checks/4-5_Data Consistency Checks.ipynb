# %% [markdown]
# # 01. Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import Data

# %%
path=r'/Users/nikolinastekovic/Library/CloudStorage/OneDrive-Personal/CF DATA ANALYICS/Immerse/4-Python/Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/nikolinastekovic/Library/CloudStorage/OneDrive-Personal/CF DATA ANALYICS/Immerse/4-Python/Instacart Basket Analysis'

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  Day_of_order  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# ...

# %%
df_ords['Day_of_order'].value_counts(dropna=False)
# Out:
# Day_of_order
# 0    600905
# 1    587478
# 2    467260
# 5    453368
# 6    448761
# 3    436972
# 4    426339
# Name: count, dtype: int64

# %%
# Create a dataframe
df_test = pd.DataFrame()

# %%
# Create a mixed type column
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# Check for mixed types - for-loop
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix

# %%
df_test['mix'].dtype
# Out:
# dtype('O')

# %%
df_test['mix'] = df_test['mix'].astype('str')

# %%
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)

# %%
df_test['mix'].dtype
# Out:
# dtype('O')

# %%
# Finding Missing Values
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
#create a subset of the dataframe containing only the values in question NaN
df_nan = df_prods[df_prods['product_name'].isnull()==True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
# New cleaned dataframw with non-missing values -False
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
# look for full duplicates within your dataframe
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
#create a new dataframe that doesn’t include the duplicates
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
# EXPORT FINAL .csv
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data','Prepared Data', 'products_checked.csv'))

# %% [markdown]
# # TASK

# %% [markdown]
# ### STEP 2  - Data Consistency Checks

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  Day_of_order  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# ...

# %%
pd.concat([df_ords.head(5), df_ords.tail(5)], axis=0, ignore_index=True)
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  Day_of_order  \
# 0           0   2539329        1    prior             1             2
# 1           1   2398795        1    prior             2             3
# 2           2    473747        1    prior             3             3
# 3           3   2254736        1    prior             4             4
# 4           4    431534        1    prior             5             4
# 5     3421078   2266710   206209    prior            10             5
# 6     3421079   1854736   206209    prior            11             4
# 7     3421080    626363   206209    prior            12             1
# 8     3421081   2977660   206209    prior            13             1
# 9     3421082    272231   206209    train            14             6
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# ...

# %% [markdown]
# 1. I notice that the first column "Unnamed: 0" has duplicate values with either column "order_id" or column "user_id". When wranklaing data in the past excercise, seems that it exporte the first index columns as a new colum. it is irrelevnt for that data.
# 2. All columns have the same count number, 3.421083e+06
# 3. columns "order_id" and "user_id" are identification numbers of the customer and the order, they don't have value in terms of max or min in this case. Their mean, min and max match.
# 4. "order number", min and max are 1 (same), but quartiles are numbers bigger then 1. This shows discrapency in th dataset.
# 5. "day of order" presents 7 days a week, but starts with 0 instead of 1.It does have all 7 days presented, so it makes sense. max i 6, meaning 7th day of the week
# 6. "time of order" represents 24 hours in a day. min is 00, midnight and max is 23, 11 pm.
# 7. "days since prior order" again there is discrepancy betwen quartiles and max value. 1st and 2nd quartile are bigger then max, which is not logical.

# %% [markdown]
# ### STEP 3 - Check for mixed-type data in your df_ords dataframe.

# %%
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)

# %% [markdown]
# Code didn't return anything, meaning there are no mixe data in the df_ords

# %% [markdown]
# ### STEP 4 - There are no mixed-type data

# %%
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col, ' mixed')
  else: print (col, ' consistent')
# Out:
# Unnamed: 0  consistent
# order_id  consistent
# user_id  consistent
# eval_set  consistent
# order_number  consistent
# Day_of_order  consistent
# order_hour_of_day  consistent
# days_since_prior_order  consistent

# %%
df_ords.dtypes
# Out:
# Unnamed: 0                  int64
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# Day_of_order                int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# ### STEP 5 - Run a check for missing values in your df_ords dataframe.

# %%
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# Day_of_order                   0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# #1 There are 206.209 missing values in column "days since prior order".
# Other columns have no missing values.

# %%
#create a subset of the dataframe containing only the values in question
df_ords_nan = df_ords[df_ords['days_since_prior_order'].isnull()==True]

# %%
df_ords_nan
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  Day_of_order  \
# 0                 0   2539329        1    prior             1             2
# 11               11   2168274        2    prior             1             2
# 26               26   1374495        3    prior             1             1
# 39               39   3343014        4    prior             1             6
# 45               45   2717275        5    prior             1             3
# ...             ...       ...      ...      ...           ...           ...
# 3420930     3420930    969311   206205    prior             1             4
# 3420934     3420934   3189322   206206    prior             1             3
# 3421002     3421002   2166133   206207    prior             1             6
# 3421019     3421019   2227043   206208    prior             1             1
# 3421069     3421069   3154581   206209    prior             1             3
#
#          order_hour_of_day  days_since_prior_order
# ...

# %% [markdown]
# 2# The Nan missing value seems to connect to the "order_number" column in a way that whenever order no=1, the value in "day since prior order" is missing.
# 3# Total number of "user_id" and "order_id" is the same as the count number of missing values (206.209). This number is the same because each time a missing value appears in the "days_since_prior_order" it is on the first order when user_id is created. And the data o previous order doesn't exist because there was no orders.
# #4 we can double-check this by looking into subset of orders per user. It is to expect that every first order will be NaN (BELOW)

# %%
df_ords[df_ords['user_id'] == 1]
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  Day_of_order  \
# 0            0   2539329        1    prior             1             2
# 1            1   2398795        1    prior             2             3
# 2            2    473747        1    prior             3             3
# 3            3   2254736        1    prior             4             4
# 4            4    431534        1    prior             5             4
# 5            5   3367565        1    prior             6             2
# 6            6    550135        1    prior             7             1
# 7            7   3108588        1    prior             8             1
# 8            8   2295261        1    prior             9             1
# 9            9   2550362        1    prior            10             4
# 10          10   1187899        1    train            11             4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# ...

# %%
df_ords[df_ords['user_id'] == 2]
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  Day_of_order  \
# 11          11   2168274        2    prior             1             2
# 12          12   1501582        2    prior             2             5
# 13          13   1901567        2    prior             3             1
# 14          14    738281        2    prior             4             2
# 15          15   1673511        2    prior             5             3
# 16          16   1199898        2    prior             6             2
# 17          17   3194192        2    prior             7             2
# 18          18    788338        2    prior             8             1
# 19          19   1718559        2    prior             9             2
# 20          20   1447487        2    prior            10             1
# 21          21   1402090        2    prior            11             1
# 22          22   3186735        2    prior            12             1
# ...

# %% [markdown]
# ### STEP 6 - Address the missing values using an appropriate method
#
# There is a value to the information NaN in this specific column. NaN suggests it is the first order from that specific customer. Data from other columns is still relevant and can be important for other calculation. this is why we don't have to do anything with this missing value. We can create a new column that will flag  new costumer, below.

# %%
df_ords_clean = df_ords
df_ords_clean['new_customer'] = df_ords['days_since_prior_order'].isnull() == True
df_ords_clean
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  Day_of_order  \
# 0                 0   2539329        1    prior             1             2
# 1                 1   2398795        1    prior             2             3
# 2                 2    473747        1    prior             3             3
# 3                 3   2254736        1    prior             4             4
# 4                 4    431534        1    prior             5             4
# ...             ...       ...      ...      ...           ...           ...
# 3421078     3421078   2266710   206209    prior            10             5
# 3421079     3421079   1854736   206209    prior            11             4
# 3421080     3421080    626363   206209    prior            12             1
# 3421081     3421081   2977660   206209    prior            13             1
# 3421082     3421082    272231   206209    train            14             6
#
# ...

# %% [markdown]
# ### REMOVING THE FIRST COLUMN

# %%
df_ords_clean = df_ords_clean.drop(columns = ['Unnamed: 0'])

# %%
df_ords_clean
# Out:
#          order_id  user_id eval_set  order_number  Day_of_order  \
# 0         2539329        1    prior             1             2
# 1         2398795        1    prior             2             3
# 2          473747        1    prior             3             3
# 3         2254736        1    prior             4             4
# 4          431534        1    prior             5             4
# ...           ...      ...      ...           ...           ...
# 3421078   2266710   206209    prior            10             5
# 3421079   1854736   206209    prior            11             4
# 3421080    626363   206209    prior            12             1
# 3421081   2977660   206209    prior            13             1
# 3421082    272231   206209    train            14             6
#
#          order_hour_of_day  days_since_prior_order  new_customer
# 0                        8                     NaN          True
# 1                        7                    15.0         False
# ...

# %% [markdown]
# ### STEP 7 - Run a check for duplicate values in your df_ords data

# %%
df_ords_dups = df_ords[df_ords.duplicated()]

# %%
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, eval_set, order_number, Day_of_order, Time_of_order, days_since_prior_order]
# Index: []

# %%
df_ords_dups.shape
# Out:
# (0, 8)

# %% [markdown]
# No duplicates were found

# %% [markdown]
# ### STEP 8 - Address the duplicates using an appropriate method.

# %% [markdown]
# No dupliacates found.

# %% [markdown]
# ### STEP 9 - Export your final, cleaned df_prods and df_ords data as “.csv” files

# %%
# Export df_prods as products_checked
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data','Prepared Data', 'products_checked.csv'))

# %%
# Export df_orders as orders_checked
df_ords_clean.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_checked.csv'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Export df_orders as orders_checked
# ----> 2 df_ords_clean.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_checked.csv'))
#
# NameError: name 'df_ords_clean' is not defined

# %% [markdown]
# ヽ(•‿•)ノ
