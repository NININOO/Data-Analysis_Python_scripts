# %% [markdown]
# # 01. Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import Data

# %%
path=r'/Users/nikolinastekovic/Library/CloudStorage/OneDrive-Personal/CF DATA ANALYICS/Immerse/4-Python/Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/nikolinastekovic/Library/CloudStorage/OneDrive-Personal/CF DATA ANALYICS/Immerse/4-Python/Instacart Basket Analysis'

# %%
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'), index_col = False)

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'), index_col = False)

# %% [markdown]
# ### Check the dimensions of the imported dataframe

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  Day_of_order  order_hour_of_day  \
# 0   2539329        1             1             2                  8
# 1   2398795        1             2             3                  7
# 2    473747        1             3             3                 12
# 3   2254736        1             4             4                  7
# 4    431534        1             5             4                 15
#
#    days_since_prior_order  new_customer
# 0                     NaN          True
# 1                    15.0         False
# 2                    21.0         False
# 3                    29.0         False
# 4                    28.0         False

# %%
df_ords = df_ords.drop(columns = 'Unnamed: 0', axis=1)

# %%
df_ords = df_ords.drop(columns = 'eval_set', axis=1)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %% [markdown]
# # 03. Merge Data

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    order_id  user_id  order_number  Day_of_order  order_hour_of_day  \
# 0   2539329        1             1             2                  8
# 1   2539329        1             1             2                  8
# 2   2539329        1             1             2                  8
# 3   2539329        1             1             2                  8
# 4   2539329        1             1             2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# 4          0   both

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
pd.concat([df_merged_large.head(15), df_merged_large.tail(15)], axis=0, ignore_index=True)
# Out:
#     order_id  user_id  order_number  Day_of_order  order_hour_of_day  \
# 0    2539329        1             1             2                  8
# 1    2539329        1             1             2                  8
# 2    2539329        1             1             2                  8
# 3    2539329        1             1             2                  8
# 4    2539329        1             1             2                  8
# 5    2398795        1             2             3                  7
# 6    2398795        1             2             3                  7
# 7    2398795        1             2             3                  7
# 8    2398795        1             2             3                  7
# 9    2398795        1             2             3                  7
# 10   2398795        1             2             3                  7
# 11    473747        1             3             3                 12
# 12    473747        1             3             3                 12
# ...

# %% [markdown]
# # 04. Export Data

# %%
df_merged_large.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.csv'))

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
df_merged_large.shape
# Out:
# (32434489, 11)
